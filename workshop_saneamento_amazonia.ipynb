# %% [markdown]
# # 💧 Workshop de Análise de Dados de Saneamento na Região Amazônica
#
# Neste notebook, vamos analisar dados públicos sobre saneamento básico em municípios da região amazônica brasileira. Exploraremos os dados com gráficos e mapas interativos usando Pydeck.

# %%
# !pip install pydeck geopandas matplotlib seaborn pandas
# Out:
# Requirement already satisfied: pydeck in ./.venv/lib/python3.8/site-packages (0.9.1)
# Requirement already satisfied: geopandas in ./.venv/lib/python3.8/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.8/site-packages (0.13.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: jinja2>=2.10.1 in ./.venv/lib/python3.8/site-packages (from pydeck) (3.1.6)
# Requirement already satisfied: numpy>=1.16.4 in ./.venv/lib/python3.8/site-packages (from pydeck) (1.24.4)
# Requirement already satisfied: packaging in ./.venv/lib/python3.8/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pyproj>=3.0.1 in ./.venv/lib/python3.8/site-packages (from geopandas) (3.5.0)
# Requirement already satisfied: fiona>=1.8.19 in ./.venv/lib/python3.8/site-packages (from geopandas) (1.10.1)
# Requirement already satisfied: shapely>=1.7.1 in ./.venv/lib/python3.8/site-packages (from geopandas) (2.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.8/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.8/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.8/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.8/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: pillow>=6.2.0 in ./.venv/lib/python3.8/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.8/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.8/site-packages (from pandas) (2025.2)
# Requirement already satisfied: cligj>=0.5 in ./.venv/lib/python3.8/site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: attrs>=19.2.0 in ./.venv/lib/python3.8/site-packages (from fiona>=1.8.19->geopandas) (25.3.0)
# Requirement already satisfied: click~=8.0 in ./.venv/lib/python3.8/site-packages (from fiona>=1.8.19->geopandas) (8.1.8)
# Requirement already satisfied: certifi in ./.venv/lib/python3.8/site-packages (from fiona>=1.8.19->geopandas) (2025.4.26)
# Requirement already satisfied: importlib-metadata in ./.venv/lib/python3.8/site-packages (from fiona>=1.8.19->geopandas) (8.5.0)
# Requirement already satisfied: click-plugins>=1.0 in ./.venv/lib/python3.8/site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.8/site-packages (from jinja2>=2.10.1->pydeck) (2.1.5)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv("cities7.csv")
df.head()
# Out:
#                    Cidade   Estado      ID  Latitude  Longitude Amazonia  \
# 0         Cruzeiro do Sul     Acre  120020 -7.636248 -72.669165      Sim
# 1              Rio Branco     Acre  120040 -9.976536 -67.822078      Sim
# 2               Arapiraca  Alagoas  270030 -9.754866 -36.661471      Não
# 3  Barra de Santo Antônio  Alagoas  270050 -9.403810 -35.511769      Não
# 4     Barra de São Miguel  Alagoas  270060 -9.826136 -35.883778      Não
#
#    População  População com acesso à água  População sem acesso à água  \
# 0    91888.0                      46566.0                      45322.0
# 1   364756.0                     195152.0                     169604.0
# 2        NaN                          NaN                          NaN
# 3        NaN                          NaN                          NaN
# 4        NaN                          NaN                          NaN
#
#    População com coleta de esgoto  ...  Parcela das moradias sem banheiro  \
# 0                             0.0  ...                             0.1996
# 1                         75383.0  ...                             0.0413
# 2                             NaN  ...                                NaN
# 3                             NaN  ...                                NaN
# 4                             NaN  ...                                NaN
#
#    Incidência de internações por diarreia  \
# 0                                   4.135
# 1                                   1.206
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    Taxa de óbitos por doenças de veiculação hídrica  \
# 0                                             0.109
# 1                                             0.055
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Consumo per capita de água  Perdas na distribuição  \
# 0                       60.00                   0.695
# 1                       97.57                   0.566
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
#
#    Índice de esgoto tratado referido à água consumida  Tarifa de água  \
# 0                                              0.000             2.63
# 1                                              0.007             2.94
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#    Custo com energia elétrica  \
# 0                  5221845.92
# 1                 15725116.30
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#    Incidência de internações totais por doenças de veiculação hídrica  \
# 0                                             26.445
# 1                                              2.604
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Moradias sem banheiro
# 0                 5337.0
# 1                 5116.0
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 28 columns]

# %%
df.info()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 839 entries, 0 to 838
# Data columns (total 28 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Cidade                                                              839 non-null    object
#  1   Estado                                                              839 non-null    object
#  2   ID                                                                  839 non-null    int64
#  3   Latitude                                                            839 non-null    float64
#  4   Longitude                                                           839 non-null    float64
#  5   Amazonia                                                            839 non-null    object
#  6   População                                                           119 non-null    float64
#  7   População com acesso à água                                         115 non-null    float64
#  8   População sem acesso à água                                         115 non-null    float64
#  9   População com coleta de esgoto                                      115 non-null    float64
#  10  População sem coleta de esgoto                                      115 non-null    float64
#  11  Parcela da população sem acesso à água                              115 non-null    float64
#  12  Parcela da população com acesso à água                              115 non-null    float64
#  13  Parcela da população sem coleta de esgoto                           115 non-null    float64
#  14  Parcela da população com coleta de esgoto                           115 non-null    float64
#  15  Densidade demográfica                                               119 non-null    float64
#  16  Área do município                                                   119 non-null    float64
#  17  Receita direta e indireta total                                     105 non-null    float64
#  18  Parcela das moradias sem banheiro                                   119 non-null    float64
#  19  Incidência de internações por diarreia                              119 non-null    float64
#  20  Taxa de óbitos por doenças de veiculação hídrica                    119 non-null    float64
#  21  Consumo per capita de água                                          115 non-null    float64
#  22  Perdas na distribuição                                              115 non-null    float64
#  23  Índice de esgoto tratado referido à água consumida                  115 non-null    float64
#  24  Tarifa de água                                                      105 non-null    float64
#  25  Custo com energia elétrica                                          113 non-null    float64
#  26  Incidência de internações totais por doenças de veiculação hídrica  119 non-null    float64
#  27  Moradias sem banheiro                                               119 non-null    float64
# dtypes: float64(24), int64(1), object(3)
# memory usage: 183.7+ KB
# Index(['Cidade', 'Estado', 'ID', 'Latitude', 'Longitude', 'Amazonia',
#        'População', 'População com acesso à água',
#        'População sem acesso à água', 'População com coleta de esgoto',
#        'População sem coleta de esgoto',
#        'Parcela da população sem acesso à água',
#        'Parcela da população com acesso à água',
#        'Parcela da população sem coleta de esgoto',
#        'Parcela da população com coleta de esgoto', 'Densidade demográfica',
#        'Área do município', 'Receita direta e indireta total',
#        'Parcela das moradias sem banheiro',
#        'Incidência de internações por diarreia',
#        'Taxa de óbitos por doenças de veiculação hídrica',
#        'Consumo per capita de água', 'Perdas na distribuição',
#        'Índice de esgoto tratado referido à água consumida', 'Tarifa de água',
#        'Custo com energia elétrica',
#        'Incidência de internações totais por doenças de veiculação hídrica',
#        'Moradias sem banheiro'],
#       dtype='object')

# %%
df_amazonia = df[df['Amazonia'] == 'Sim'].copy()
df_amazonia.shape
df_amazonia.head()
# Out:
#                Cidade    Estado      ID  Latitude  Longitude Amazonia  \
# 0     Cruzeiro do Sul      Acre  120020 -7.636248 -72.669165      Sim
# 1          Rio Branco      Acre  120040 -9.976536 -67.822078      Sim
# 21             Macapá     Amapá  160030  0.040153 -51.056959      Sim
# 22            Santana     Amapá  160060 -0.030707 -51.178967      Sim
# 23  Careiro da Várzea  Amazonas  130115 -3.197024 -59.825910      Sim
#
#     População  População com acesso à água  População sem acesso à água  \
# 0     91888.0                      46566.0                      45322.0
# 1    364756.0                     195152.0                     169604.0
# 21   442933.0                     240857.0                     202076.0
# 22   107618.0                      48518.0                      59100.0
# 23    19637.0                        549.0                      19088.0
#
#     População com coleta de esgoto  ...  Parcela das moradias sem banheiro  \
# 0                              0.0  ...                             0.1996
# 1                          75383.0  ...                             0.0413
# 21                         35660.0  ...                             0.0229
# 22                          1415.0  ...                             0.0368
# 23                             0.0  ...                             0.2130
#
#     Incidência de internações por diarreia  \
# 0                                    4.135
# 1                                    1.206
# 21                                   1.806
# 22                                   8.549
# 23                                   2.037
#
#     Taxa de óbitos por doenças de veiculação hídrica  \
# 0                                              0.109
# 1                                              0.055
# 21                                             0.000
# 22                                             0.279
# 23                                             0.000
#
#     Consumo per capita de água  Perdas na distribuição  \
# 0                        60.00                   0.695
# 1                        97.57                   0.566
# 21                       65.70                   0.714
# 22                       90.82                   0.584
# 23                       20.93                   0.700
#
#     Índice de esgoto tratado referido à água consumida  Tarifa de água  \
# 0                                               0.000             2.63
# 1                                               0.007             2.94
# 21                                              0.222             3.33
# 22                                              0.000             2.45
# 23                                              0.000             0.56
#
#     Custo com energia elétrica  \
# 0                   5221845.92
# 1                  15725116.30
# 21                  7663301.09
# 22                  2220334.47
# 23                    95088.35
#
#     Incidência de internações totais por doenças de veiculação hídrica  \
# 0                                              26.445
# 1                                               2.604
# 21                                              2.280
# 22                                              9.664
# 23                                              2.037
#
#     Moradias sem banheiro
# 0                  5337.0
# 1                  5116.0
# 21                 2828.0
# 22                 1060.0
# 23                 1231.0
#
# [5 rows x 28 columns]

# %%
import pydeck as pdk

df_mapa = df_amazonia[
    ['Cidade', 'Latitude', 'Longitude', 'Parcela da população com acesso à água']
].dropna()

layer = pdk.Layer(
    "ScatterplotLayer",
    data=df_mapa,
    get_position='[Longitude, Latitude]',
    get_fill_color='[255, 100 * Parcela da população com acesso à água, 100, 180]',
    get_radius=10000,
    pickable=True
)

view_state = pdk.ViewState(latitude=-4.5, longitude=-60, zoom=4.2)

deck = pdk.Deck(
    layers=[layer],
    initial_view_state=view_state,
    tooltip={"text": "{Cidade}\nAcesso à água: {Parcela da população com acesso à água}%"}
)

deck.show()
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~9.0.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: -4.5,
#     &quot;longitude&quot;: -60,
#     &quot;zoom&quot;: 4.2
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ScatterplotLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;Cidade&quot;: &quot;Cruzeiro do Sul&quot;,
#           &quot;Latitude&quot;: -7.6362478,
#           &quot;Longitude&quot;: -72.6691649,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.507
#         },
#         {
#           &quot;Cidade&quot;: &quot;Rio Branco&quot;,
#           &quot;Latitude&quot;: -9.9765362,
#           &quot;Longitude&quot;: -67.8220778,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.535
#         },
#         {
#           &quot;Cidade&quot;: &quot;Macap\u00e1&quot;,
#           &quot;Latitude&quot;: 0.0401529,
#           &quot;Longitude&quot;: -51.0569588,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.544
#         },
#         {
#           &quot;Cidade&quot;: &quot;Santana&quot;,
#           &quot;Latitude&quot;: -0.0307068,
#           &quot;Longitude&quot;: -51.1789666,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.451
#         },
#         {
#           &quot;Cidade&quot;: &quot;Careiro da V\u00e1rzea&quot;,
#           &quot;Latitude&quot;: -3.197024,
#           &quot;Longitude&quot;: -59.8259104,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.028
#         },
#         {
#           &quot;Cidade&quot;: &quot;Coari&quot;,
#           &quot;Latitude&quot;: -4.0885957,
#           &quot;Longitude&quot;: -63.1431166,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.159
#         },
#         {
#           &quot;Cidade&quot;: &quot;Humait\u00e1&quot;,
#           &quot;Latitude&quot;: -7.5099404,
#           &quot;Longitude&quot;: -63.0248674,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.995
#         },
#         {
#           &quot;Cidade&quot;: &quot;Iranduba&quot;,
#           &quot;Latitude&quot;: -3.2758203,
#           &quot;Longitude&quot;: -60.1867429,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.582
#         },
#         {
#           &quot;Cidade&quot;: &quot;Itacoatiara&quot;,
#           &quot;Latitude&quot;: -3.1477898,
#           &quot;Longitude&quot;: -58.4461041,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.587
#         },
#         {
#           &quot;Cidade&quot;: &quot;Manacapuru&quot;,
#           &quot;Latitude&quot;: -3.2996768,
#           &quot;Longitude&quot;: -60.6213528,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.903
#         },
#         {
#           &quot;Cidade&quot;: &quot;Manaus&quot;,
#           &quot;Latitude&quot;: -3.1316333,
#           &quot;Longitude&quot;: -59.9825041,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.995
#         },
#         {
#           &quot;Cidade&quot;: &quot;Manicor\u00e9&quot;,
#           &quot;Latitude&quot;: -5.804618,
#           &quot;Longitude&quot;: -61.289483,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.479
#         },
#         {
#           &quot;Cidade&quot;: &quot;Mau\u00e9s&quot;,
#           &quot;Latitude&quot;: -3.3795798,
#           &quot;Longitude&quot;: -57.7196072,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.494
#         },
#         {
#           &quot;Cidade&quot;: &quot;Novo Air\u00e3o&quot;,
#           &quot;Latitude&quot;: -2.6260236,
#           &quot;Longitude&quot;: -60.9434406,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 1.0
#         },
#         {
#           &quot;Cidade&quot;: &quot;Parintins&quot;,
#           &quot;Latitude&quot;: -2.6344567,
#           &quot;Longitude&quot;: -56.7319324,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.996
#         },
#         {
#           &quot;Cidade&quot;: &quot;Presidente Figueiredo&quot;,
#           &quot;Latitude&quot;: -2.0486359,
#           &quot;Longitude&quot;: -60.0236658,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.554
#         },
#         {
#           &quot;Cidade&quot;: &quot;Rio Preto da Eva&quot;,
#           &quot;Latitude&quot;: -2.6990647,
#           &quot;Longitude&quot;: -59.7012494,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.864
#         },
#         {
#           &quot;Cidade&quot;: &quot;Tabatinga&quot;,
#           &quot;Latitude&quot;: -4.2327349,
#           &quot;Longitude&quot;: -69.9263372,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.282
#         },
#         {
#           &quot;Cidade&quot;: &quot;Tef\u00e9&quot;,
#           &quot;Latitude&quot;: -3.3485276,
#           &quot;Longitude&quot;: -64.7102278,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.817
#         },
#         {
#           &quot;Cidade&quot;: &quot;A\u00e7ail\u00e2ndia&quot;,
#           &quot;Latitude&quot;: -4.9515026,
#           &quot;Longitude&quot;: -47.500732,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 1.0
#         },
#         {
#           &quot;Cidade&quot;: &quot;Alc\u00e2ntara&quot;,
#           &quot;Latitude&quot;: -2.4084996,
#           &quot;Longitude&quot;: -44.4174143,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.342
#         },
#         {
#           &quot;Cidade&quot;: &quot;Bacabal&quot;,
#           &quot;Latitude&quot;: -4.2318132,
#           &quot;Longitude&quot;: -44.781167,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.805
#         },
#         {
#           &quot;Cidade&quot;: &quot;Balsas&quot;,
#           &quot;Latitude&quot;: -7.53214,
#           &quot;Longitude&quot;: -46.037163,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.864
#         },
#         {
#           &quot;Cidade&quot;: &quot;Barra do Corda&quot;,
#           &quot;Latitude&quot;: -5.496823,
#           &quot;Longitude&quot;: -45.248496,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.398
#         },
#         {
#           &quot;Cidade&quot;: &quot;Buriticupu&quot;,
#           &quot;Latitude&quot;: -4.3227472,
#           &quot;Longitude&quot;: -46.4516989,
#           &quot;Parcela da popula\u00e7\u00e3o com acesso \u00e0 \u00e1gua&quot;: 0.814
#         },
#         {
#           &quot;Cidade&quot;: &quot;Cod\u00f3&quot;,
#           &quot;Latitude&quot;: -4.455623,
#           &quot;Longitude&quot;: -43.892

# %%
import pydeck as pdk

# 2014 locations of car accidents in the UK
UK_ACCIDENTS_DATA = ('https://raw.githubusercontent.com/uber-common/'
                     'deck.gl-data/master/examples/3d-heatmap/heatmap-data.csv')

# Define a layer to display on a map
layer = pdk.Layer(
    'HexagonLayer',
    UK_ACCIDENTS_DATA,
    get_position=['lng', 'lat'],
    auto_highlight=True,
    elevation_scale=50,
    pickable=True,
    elevation_range=[0, 3000],
    extruded=True,                 
    coverage=1)

# Set the viewport location
view_state = pdk.ViewState(
    longitude=-1.415,
    latitude=52.2323,
    zoom=6,
    min_zoom=5,
    max_zoom=15,
    pitch=40.5,
    bearing=-27.36)

# Render
r = pdk.Deck(layers=[layer], initial_view_state=view_state)
r.to_html('demo.html')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df_amazonia['Parcela da população sem coleta de esgoto'], bins=20, kde=True)
plt.title('Distribuição da população sem coleta de esgoto (%)')
plt.xlabel('Parcela da população sem coleta de esgoto (%)')
plt.ylabel('Número de Municípios')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_amazonia,
    x='Parcela da população sem coleta de esgoto',
    y='Incidência de internações por diarreia',
    hue='Estado'
)
plt.title('Internações por diarreia vs. Falta de Coleta de Esgoto')
plt.xlabel('Parcela da população sem coleta de esgoto (%)')
plt.ylabel('Internações por diarreia (por 10 mil hab.)')
plt.legend(loc='upper right')
plt.grid(True)

# %% [markdown]
# ## 🔍 Atividade
#
# Escolha uma variável que você acha relevante para a qualidade do saneamento básico (ex: **Moradias sem banheiro**, **Perdas na distribuição**, **Tarifa de água**) e:
#
# 1. Crie um gráfico com `seaborn` ou `matplotlib` para analisar sua distribuição.
# 2. Crie um mapa com `pydeck` para visualizar espacialmente essa variável.
# 3. Compartilhe com os colegas suas descobertas.
